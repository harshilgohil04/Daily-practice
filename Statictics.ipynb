# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline 
import scipy.stats as stats

# %%
# importing the required function
from scipy.stats import uniform

# selecting the seed for reproducibility
np.random.seed(1)

# creating a uniform distribution population of size 100000
uniform_pop = uniform.rvs(0,10,size=100000)

# visulizing the uniform distribution
plt.hist(uniform_pop)
plt.title("uniform distrubution population")
plt.xlabel("x~u(0,10)")
plt.ylabel("count")
plt.show()

# %%
# set the seed for reproducibility
np.random.seed(1)

# set the sample size to 5
n= 5

# list to store sample means
sample_means=[]

# iterate the loop to draw multiple sample
for j in range(500):
    #draw a sample of size n
    sample= np.random.choice(uniform_pop,size=n)
    #calculate the sample mean
    sample_mean= np.mean(sample)
    # append the sample mean to sample_mean list
    sample_means.append(sample_mean)
#plot histogram of sample means
sns.displot(sample_means,kde=True)
plt.title("distribution of sample means for n= " + str(n))
plt.xlabel('sample mean')
plt.ylabel('count')
plt.show()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# set the seed for reproducibility
np.random.seed(1)

# set the sample size to 15
n= 15

# list to store sample means
sample_means=[]

# iterate the loop to draw multiple sample
for j in range(500):
    #draw a sample of size n
    sample= np.random.choice(uniform_pop,size=n)
    #calculate the sample mean
    sample_mean= np.mean(sample)
    # append the sample mean to sample_mean list
    sample_means.append(sample_mean)
#plot histogram of sample means
sns.displot(sample_means,kde=True)
plt.title("distribution of sample means for n= " + str(n))
plt.xlabel('sample mean')
plt.ylabel('count')
plt.show()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 1 sample : ttest1_samp = data,mean/mu
# 2 sample independent ttest_ind= 2 data as input
# paired test : ttest_rel = 2 data as input 
# chi - square : stats.chi2_contingency(df, correction = False)
