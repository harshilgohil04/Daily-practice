# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
data=sns.load_dataset("mpg")
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data1=data.isnull().sum()
data1
# Out:
# 6

# %%
data.dropna(inplace= True)
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data2=pd.get_dummies(data,columns=["cylinders","model_year","origin"],drop_first=True)
data2.head()
# Out:
#     mpg  displacement  horsepower  weight  acceleration  \
# 0  18.0         307.0       130.0    3504          12.0
# 1  15.0         350.0       165.0    3693          11.5
# 2  18.0         318.0       150.0    3436          11.0
# 3  16.0         304.0       150.0    3433          12.0
# 4  17.0         302.0       140.0    3449          10.5
#
#                         name  cylinders_4  cylinders_5  cylinders_6  \
# 0  chevrolet chevelle malibu        False        False        False
# 1          buick skylark 320        False        False        False
# 2         plymouth satellite        False        False        False
# 3              amc rebel sst        False        False        False
# 4                ford torino        False        False        False
#
#    cylinders_8  ...  model_year_75  model_year_76  model_year_77  \
# 0         True  ...          False          False          False
# 1         True  ...          False          False          False
# ...

# %%
x=data2[["mpg","horsepower","weight",
        "acceleration","cylinders_4","cylinders_5","cylinders_6","cylinders_8","model_year_75","model_year_76","model_year_77",
        "model_year_78","model_year_79","model_year_80","model_year_81","model_year_82","origin_japan","origin_usa"]]


y=data2["displacement"]

# %%
x
# Out:
#       mpg  horsepower  weight  acceleration  cylinders_4  cylinders_5  \
# 0    18.0       130.0    3504          12.0        False        False
# 1    15.0       165.0    3693          11.5        False        False
# 2    18.0       150.0    3436          11.0        False        False
# 3    16.0       150.0    3433          12.0        False        False
# 4    17.0       140.0    3449          10.5        False        False
# ..    ...         ...     ...           ...          ...          ...
# 393  27.0        86.0    2790          15.6         True        False
# 394  44.0        52.0    2130          24.6         True        False
# 395  32.0        84.0    2295          11.6         True        False
# 396  28.0        79.0    2625          18.6         True        False
# 397  31.0        82.0    2720          19.4         True        False
#
#      cylinders_6  cylinders_8  model_year_75  model_year_76  model_year_77  \
# ...

# %%
y
# Out:
# 0      307.0
# 1      350.0
# 2      318.0
# 3      304.0
# 4      302.0
#        ...
# 393    140.0
# 394     97.0
# 395    135.0
# 396    120.0
# 397    119.0
# Name: displacement, Length: 392, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=150)

# %%
x_train
# Out:
#       mpg  horsepower  weight  acceleration  cylinders_4  cylinders_5  \
# 258  20.6       105.0    3380          15.8        False        False
# 203  29.5        71.0    1825          12.2         True        False
# 42   12.0       180.0    4955          11.5        False        False
# 364  26.6       105.0    3725          19.0        False        False
# 43   13.0       170.0    4746          12.0        False        False
# ..    ...         ...     ...           ...          ...          ...
# 254  20.2        85.0    2965          15.8        False        False
# 361  25.4       116.0    2900          12.6        False        False
# 308  33.5        90.0    2556          13.2         True        False
# 25   10.0       215.0    4615          14.0        False        False
# 230  15.5       170.0    4165          11.4        False        False
#
#      cylinders_6  cylinders_8  model_year_75  model_year_76  model_year_77  \
# ...

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 436.69
# R-squared: 0.96
